# %%
# newton method with modified Hessian




using Toms566



function newtmin( obj, x0; maxit=500, optTol=1e-6)
# Minimize a function f using Newton’s method.
# obj: a function that evaluates the objective value,
# gradient, and Hessian at a point x, i.e.,
# (f, g, H) = obj(x)
# x0: starting point.
# maxIts (optional): maximum number of iterations.
# optTol (optional): optimality tolerance based on
# ||grad(x)|| <= optTol*||grad(x0)||
    
    f_0 = obj.obj(x0);
    grad_0 = obj.grd(x0);
    Hes_0 = obj.hes(x0);
    Hes_0 = Hes_0-min(eigmin(Hes_0)-1e-3,0)*eye(length(x0));
        
    x = x0;
    f_x = f_0;
    grad_x = grad_0;   
    Hes_x = Hes_0;
    
    #Counts the iteratives.
    int = 0;
    
    while optTol * norm(grad_0,2) <= norm(grad_x,2)
        
        int=int+1;
        # if the iteratives number is greater than maxit, break down.
        if int >= maxit
            break
        end
        
    # applying netwon method
    
    # determine the direction.
    
        dx = - inv(Hes_x) *  grad_x ;
    
        t=1;
        bt=0;
        at=grad_x' * dx;

            while obj.obj(x+t*dx) >= obj.obj(x)+alpha*t*at[1]
        
                t= t * beta;
            end # back tracking
        
        
        x=x+dx*t;
    
        f_x=obj.obj(x);
        grad_x = obj.grd(x);
        Hes_x = obj.hes(x);
        Hes_x = Hes_x - min(eigmin(Hes_x)-1e-3,0)*eye(length(x0));
    
    
    
    
    end # while newton M
    
    return(x, int)   
end   # function
##############################
###### The first problem
##############################
beta = 0.5;
alpha = 0.3;
for i = 1:18
    println(i,"th function")
    p=Problem(i)
    x0=p.x0;
    (x,int)=newtmin(p,x0)
    println("minf=", p.obj(x),"|gradf|=",norm(p.grd(x),2),"mineig=",eigmin(p.hes(x)),"iter=",int)
end
# Out:
# 1th function
# minf=1.4006825805827448e-13|gradf|=6.581947376456882e-6mineig=1.4327652425075428iter=14
# 2th function
# minf=0.3705918358081918|gradf|=1.0455797182821736mineig=-7.091361751815526iter=500
# 3th function
# minf=1.1279327696199563e-8|gradf|=9.701953934166454e-11mineig=0.13965436330168735iter=2
# 4th function
# minf=1.162195220949106e-6|gradf|=0.019796499987636943mineig=5.419133223057149e-6iter=194
# 5th function
# minf=9.565029308898072e-8|gradf|=9.122697575978605e-5mineig=0.0009136005045418169iter=14
# 6th function
# minf=2392.698666372734|gradf|=30662.484270769346mineig=-669344.9065690533iter=6
# 7th function
# minf=12.290699367975991|gradf|=72.48727062381955mineig=-180.76167955770123iter=500
# 8th function
# minf=47.768233874747295|gradf|=73.98231922081709mineig=27.5404069394105iter=11
# 9th function
# minf=88.05239989273062|gradf|=0.43560489952245857mineig=-13.09719248501692iter=500
# 10th function
# minf=1.3590842481722266e-20|gradf|=1.2379874905192022e-5mineig=1.9999999999999998iter=6
# 11th function
# minf=1.619842048856204e6|gradf|=491163.49921496486mineig=-3935.2956916240864iter=500
# 12th function
# minf=4.4582422849630366e-5|gradf|=3.969400503742381e-5mineig=1.7122975429154146e-5iter=106
# 13th function
# minf=8.784709282244109e-9|gradf|=9.014811244784504e-5mineig=-0.04266495819629897iter=500
# 14th function
# minf=445.31603592314383|gradf|=984.9107163838681mineig=-679.4984504860586iter=500
# 15th function
# minf=2361.5306603558884|gradf|=1421.9513223722865mineig=-529.3627448601255iter=500
# 16th function
# minf=4.872682553114913e-13|gradf|=2.1080815841098406e-6mineig=0.30146484469749124iter=7
# 17th function
# minf=9.73637513235773e-11|gradf|=0.00020562049740512257mineig=0.7195934807714365iter=38
# 18th function
# minf=0.010412189440993511|gradf|=1.7689805256300337mineig=-212.34651902499095iter=500

# %%
using Toms566


#for i = 1:18
    obj=Problem(1)
    x0=obj.x0;
maxit=500;
optTol=1e-6;



beta = 0.5;
alpha = 0.3;
alpha2 = 0.4;




#function newtmin( obj, x0; maxit=500, optTol=1e-6)
# Minimize a function f using Newton’s method.
# obj: a function that evaluates the objective value,
# gradient, and Hessian at a point x, i.e.,
# (f, g, H) = obj(x)
# x0: starting point.
# maxIts (optional): maximum number of iterations.
# optTol (optional): optimality tolerance based on
# ||grad(x)|| <= optTol*||grad(x0)||
    f_0 = obj.obj(x0);
    grad_0 = obj.grd(x0);
    Hes_0 = obj.hes(x0);
    Hes_0 = Hes_0-min(eigmin(Hes_0)-1e-3,0)*eye(length(x0));
           
    #Counts the iteratives.
    int = 0;
    x = x0;
    f_x = f_0;
    grad_x = grad_0;   
    Hes_x = Hes_0;
    H = inv(Hes_x);
    while optTol * norm(grad_0,2) <= norm(grad_x,2)
        
        int=int+1;
        # if the iteratives number is greater than maxit, break down.
        if int >= maxit
            break
        end

    # applying netwon method
    
    # determine the direction.
    
        dx = - H *  grad_x ;
    
        t=1;
        bt=0;
        at=grad_x' * dx;

        while obj.obj(x+t*dx) >= obj.obj(x)+alpha*t*at[1] 
        
                t= t * beta;
        
        end # back tracking

    
        s = dx * t;
        y = obj.grd(x+s)-obj.grd(x);
        rho = s'*y;
        r= 1/rho[1];
    H = H + (rho[1]+ (y' * H * y)[1])*(s*s')*r^2 - r*(H * y*s' + s*y'*H);
        #H = (eye(length(x0)) -r * s * y' ) * H * (eye(length(x0)) -r * y * s' ) + r * s * s';
    
        x = x + t*dx;
        grad_x = obj.grd(x);
    
    end # while newton M
    
    #return(x, int)   
#end   # function
##############################
###### The first problem
##############################


#end

# %%
# newton method with B


using Toms566





function newtmin( obj, x0; maxit=100, optTol=1e-7)
# Minimize a function f using Newton’s method.
# obj: a function that evaluates the objective value,
# gradient, and Hessian at a point x, i.e.,
# (f, g, H) = obj(x)
# x0: starting point.
# maxIts (optional): maximum number of iterations.
# optTol (optional): optimality tolerance based on
# ||grad(x)|| <= optTol*||grad(x0)||
    f_0 = obj.obj(x0);
    grad_0 = obj.grd(x0);
    Hes_0 = obj.hes(x0);
    Hes_0 = Hes_0-min(eigmin(Hes_0)-1e-3,0)*eye(length(x0));
           
    #Counts the iteratives.
    int = 0;
    x = x0;
    f_x = f_0;
    grad_x = grad_0;   
    Hes_x = Hes_0;
    H = inv(Hes_x);
    while optTol * norm(grad_0,2) <= norm(grad_x,2)
        
        int=int+1;
        # if the iteratives number is greater than maxit, break down.
        if int >= maxit
            break
        end

    # applying netwon method
    
    # determine the direction.
    
        dx = - H *  grad_x ;
    
        t=1;
        bt=0;
        at=grad_x' * dx;

        while obj.obj(x+t*dx) >= obj.obj(x)+alpha*t*at[1] 
        
                t= t * beta;
        
        end # back tracking
    
        s = dx * t;
        y = obj.grd(x+s)-obj.grd(x);
        rho = s'*y;
        r= 1/rho[1];
    H = H + (rho[1]+ (y' * H * y)[1])*(s*s')*r^2 - r*(H * y*s' + s*y'*H);
        #H = (eye(length(x0)) -r * s * y' ) * H * (eye(length(x0)) -r * y * s' ) + r * s * s';
    
        x = x + t*dx;
        grad_x = obj.grd(x);
    
    end # while newton M
    
    return(x, int)   
end   # function
##############################
###### The first problem
##############################
# main()
beta = 0.5;
alpha = 0.4;
alpha2 = 0;
for i = 1:10
    obj=Problem(i)
    x0=obj.x0;
    (x, int)= newtmin(obj,x0);
    println( obj.obj(x)," ", norm(obj.grd(x),2)," ",int)

end
# Out:
# 2.9924339439956404e-12 6.401523965877033e-5 25
# 8.964756941642933e-15 1.0818711123135934e-7 83
# 1.1279327696189195e-8 7.947786701381712e-13 3
# 3.232590057492775e-9 0.6019890842964389 100
# 2.5220210263030768e-14 2.4277889276456895e-7 35
# 2252.1774240648706 10032.985003443395 19
# 6.4682992581853164e-6 2.8936793502465312e-6 79
# 2.2135737244233673 7.843645713758087 30
# 88.0338308706372 0.032162791075521 93
# 1.4403223474969768e-17 0.0023488251344040557 11

# %%
using Toms566


function newtmin( obj, x0; maxit=500, optTol=1e-10)
# Minimize a function f using Newton’s method.
# obj: a function that evaluates the objective value,
# gradient, and Hessian at a point x, i.e.,
# (f, g, H) = obj(x)
# x0: starting point.
# maxIts (optional): maximum number of iterations.
# optTol (optional): optimality tolerance based on
# ||grad(x)|| <= optTol*||grad(x0)||
    
    f_0 = obj.obj(x0);
    grad_0 = obj.grd(x0);
    Hes_0 = obj.hes(x0);
    Hes_0 = Hes_0-min(eigmin(Hes_0)-1e-3,0)*eye(length(x0));
        
    x = x0;
    f_x = f_0;
    grad_x = grad_0;   
    Hes_x = Hes_0;
    
    #Counts the iteratives.
    int = 0;
    
    while optTol * norm(grad_0,2) <= norm(grad_x,2)
        
        int=int+1;
        # if the iteratives number is greater than maxit, break down.
        if int >= maxit
            break
        end
        
    # applying netwon method
    
    # determine the direction.
    
        dx = - inv(Hes_x) *  grad_x ;
    
        t=1;
        bt=0;
        at=grad_x' * dx;

            while obj.obj(x+t*dx) >= obj.obj(x)+alpha*t*at[1]
        
                t= t * beta;
            end # back tracking
        
        
        x=x+dx*t;
    
        f_x=obj.obj(x);
        grad_x = obj.grd(x);
        Hes_x = obj.hes(x);
        Hes_x = Hes_x - min(eigmin(Hes_x)-1e-3,0)*eye(length(x0));
    
    
    
    
    end # while newton M
    
    return(x, int)   
end   # function
##############################
###### The first problem
##############################
beta = 0.1;
alpha = 0.2;
    p=Problem(6)
    x0=ones(40) * 0.9;
    (x,int)=newtmin(p,x0);
    println("minf=", p.obj(x),"|gradf|=",norm(p.grd(x),2),"iter=",int)
# Out:
# minf=49.35393862386345|gradf|=178.28742608540117iter=500

# %%
using Toms566


function newtmin( obj, x0; maxit=800, optTol=1e-8)
# Minimize a function f using Newton’s method.
# obj: a function that evaluates the objective value,
# gradient, and Hessian at a point x, i.e.,
# (f, g, H) = obj(x)
# x0: starting point.
# maxIts (optional): maximum number of iterations.
# optTol (optional): optimality tolerance based on
# ||grad(x)|| <= optTol*||grad(x0)||
    
    f_0 = obj.obj(x0);
    grad_0 = obj.grd(x0);
    Hes_0 = obj.hes(x0);
    Hes_0 = Hes_0-min(eigmin(Hes_0)-1e-3,0)*eye(length(x0));
        
    x = x0;
    f_x = f_0;
    grad_x = grad_0;   
    Hes_x = Hes_0;
    
    #Counts the iteratives.
    int = 0;
    
    while optTol * norm(grad_0,2) <= norm(grad_x,2)
        
        int=int+1;
        # if the iteratives number is greater than maxit, break down.
        if int >= maxit
            break
        end
        
    # applying netwon method
    
    # determine the direction.
    
        dx = - inv(Hes_x) *  grad_x ;
    
        t=1;
        bt=0;
        at=grad_x' * dx;

            while obj.obj(x+t*dx) >= obj.obj(x)+alpha*t*at[1]
        
                t= t * beta;
            end # back tracking
        
        
        x=x+dx*t;
    
        f_x=obj.obj(x);
        grad_x = obj.grd(x);
        Hes_x = obj.hes(x);
        Hes_x = Hes_x - min(eigmin(Hes_x)-1e-3,0)*eye(length(x0));
    
    
    
    
    end # while newton M
    
    return(x, int)   
end   # function
##############################
###### The first problem
##############################
beta = 0.5;
alpha = 0.3;
    p=Problem(15)
x0=p.x0;
    (x,int)=newtmin(p,x0);
    println("minf=", p.obj(x),"|gradf|=",norm(p.grd(x),2),"iter=",int)
# Out:
# minf=2342.838743598678|gradf|=1411.4724363759512iter=800

# %%
using Toms566
